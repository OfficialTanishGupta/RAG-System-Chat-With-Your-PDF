# %%
import sys
sys.path.append("../src")

# %%
from pdf_loader import load_pdf
from chunking import chunk_text
from embeddings import create_embeddings
from retriever import VectorStore
from qa_system import answer_question
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
text = load_pdf("../data/v8_engine_guide.pdf")

print(text[:500])
# Out:
# Understanding the Car V8 Engine
# A V8 engine is one of the most powerful and iconic internal combustion engines used in cars. The
# term V8 refers to the engine's configuration: eight cylinders arranged in a V shape. These engines
# are commonly used in high-performance vehicles, muscle cars, trucks, and luxury cars because
# they produce strong power and torque.
# 1. What is a V8 Engine?
# A V8 engine contains eight cylinders arranged in two banks of four cylinders each. These two banks
# are positioned at

# %%
chunks = chunk_text(text)

print(len(chunks))
# Out:
# 5

# %%
embeddings = create_embeddings(chunks)

# %%
vector_store = VectorStore(embeddings, chunks)

# %%
query = "What is this document about?"

answer = answer_question(query, vector_store)

print(answer)
# Out:
# Based on the document:
#
# ins eight cylinders arranged in two banks of four cylinders each. These two banks
# are positioned at an angle forming a V shape. A crankshaft connects all the pistons and converts
# the up-and-down piston motion into rotational motion that ultimately powers the car's wheels.
# 2. Main Components of a V8 Engine
# Component
# Function
# Cylinders
# Chambers where fuel and air combust to produce power
# Pistons
# Move up and down inside cylinders
# Crankshaft
# Converts piston motion into rotational motion
# Camshaft
# Con Understanding the Car V8 Engine
# A V8 engine is one of the most powerful and iconic internal combustion engines used in cars. The
# term V8 refers to the engine's configuration: eight cylinders arranged in a V shape. These engines
# are commonly used in high-performance vehicles, muscle cars, trucks, and luxury cars because
# they produce strong power and torque.
# 1. What is a V8 Engine?
# A V8 engine contains eight cylinders arranged in two banks of four cylinders each. These two banks
# are positioned at   The piston compresses the mixture. 3. Power – The spark
# plug ignites the mixture creating power. 4. Exhaust – Burned gases exit the cylinder. With eight
# cylinders working together, the engine produces smooth and powerful performance.
# 4. Advantages of V8 Engines
#  High power output  Strong acceleration  Smooth engine balance  Ideal for heavy vehicles and
# performance cars
# 5. Disadvantages of V8 Engines
#  Higher fuel consumption  Heavier engine weight  More complex and expensive to manufactur
